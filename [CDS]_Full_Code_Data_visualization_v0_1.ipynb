# %% [markdown]
# 9/18(금) my SUNI CDS 데이터시각화 - SK브로드밴드 전태일M

# %% [markdown]
# ## [Theme 1] Matplotlib
#     - Line Plot
#     - Multi Line Plot
#       * Exercise
#     - Scatter
#     - bar
#     - subplot (Figure 분할)
#       * Exercise
#     - wordcloud
#       * Exercise

# %%
# 시각화 진행을 위한 Library Call
import matplotlib.pyplot as plt
import numpy as np

# %%
# 한글 폰트 설치 (한글 깨짐 현상 발생)
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
plt.rc('font', family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 11 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %% [markdown]
# # (Example) Mathplotlib을 이용한 시각화 (Line Plot)

# %%
# plt 를 사용하여, plot draw
# x축 : x의 요소 값, y축 : y의 요소 값
# 'ro-' 1) color / 2) marker / 3) linestyle
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0,6, 0, 20])
plt.show()

# %%
# plt.plot(x,y) 
# x축 : x의 요소 값, y축 : y의 요소 값
x = np.arange(10)
y = x**2
plt.plot(x,y)

# %%
# plt.plot(x,y) 
# x축 : x의 요소 값, y축 : y의 요소 값
x = np.arange(10)
y = x**2

plt.plot(x,y)
plt.annotate('here', xy=(4,16), xytext=(5, 20), arrowprops={'color':'green'})

plt.text(7, 70, '$y=x^2$')
# Out:
# Text(7, 70, '$y=x^2$')

# %% [markdown]
# # (Example) Mathplotlib을 이용한 시각화 (Multi Line Plot)

# %%
# x, y, y2에 대한 세팅
x = np.arange(10)
y = x**2
y2 = x*5 + 2

# plot draw
plt.plot(x, y, 'b', label='first')
plt.plot(x, y2, 'r', label = 'second')

# legend setting
plt.legend(loc = 'upper right')

# %%
import numpy as np
# np.arange(start, stop, step)
t = np.arange(0,5,0.2)

# %%
# 여러 그래프 겹처서 그리기
plt.plot(t, t, 'r--', label='a')
plt.plot(t, t**2,'bs', label='b')
plt.plot(t, t**3, 'g^', label ='c')
# plt.legend(loc=1)
plt.legend(loc="upper right")


# 추가적으로, x, y 축 라벨 설정
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.title('hello')
plt.show()

# %% [markdown]
# ## (Exercise) Mathplotlib을 이용한 시각화 (Multi Line Plot) - Question 2개

# %%
# x, y 에 대한 세팅
x = np.arange(20)
y = x**2 +20

# %%
# Question 1
# plot 1 : (x, 2*y, 'r--', label='data1')
# plot 2 : (x, 3*y, 'r^.', label='data2')
# xlabel("x_axis"), ylabel("y_axis"), title("visualization")
# legend ("upper right")
# TODO 1
plt.plot(x, 2*y, 'c--', label='data1')
plt.plot(x, 3*y, 'g^', label='data2')
plt.legend(loc="upper right")
# TODO 2
plt.xlabel('x_axis')
plt.ylabel('y_axis')
plt.title('visualization')
plt.show()

# %%
# x, y, z에 대한 세팅
x = np.arange(10)
y = x**3 -20
z = 2*x + 3

# %%
# Question 2
# plot 1 : (x, 2*y, 'c--', label='data1')
# plot 2 : (x, 3*y, 'r^', label='data2')
# plot 3 : (x, 5*z+2, 'bs-', label='data3')
# xlabel("x"), ylabel("y"), title("viz")
# legend ("upper center")
# TODO 1
plt.plot(x, 2*y, 'c--', label='data1')
plt.plot(x, 3*y, 'r^', label='data2')
plt.plot(x, 5*z+2, 'bs-', label='data3')
plt.legend(loc="upper center")
# TODO 2
plt.xlabel('x')
plt.ylabel('y')
plt.title('viz')
plt.show()

# %% [markdown]
# # (Example) Mathplotlib을 이용한 시각화 (Scatter Plot)
#
# >  Scattter Plot

# %% [markdown]
# Scatter Plot Parameter
# (c : 색상
# s : 크기)

# %%
# np.random.randint : 정수형 난수 1개 생성
# np.random.rand : 균일 분포에서 난수 Data 생성
# np.random. randn : 가우시안 표준 정규 분포에서 난수 Data 생성

data = {
    'a':np.arange(50),
    # 균일분포에서, 0부터 50사이에 랜덤하게 50개
    'c':np.random.randint(0,50,50),
    # 가우시안 정규분포에서, 0부터 50사이에 랜덤하게 50개
    'd':np.random.randn(50)
}

# 데이터에 대한 노이즈를 일부러 넣었음
data['b'] = data['a'] + 10 * np.random.randn(50)
# 절대값 이용해서, 곱하기 100정도 했음
data['d'] = np.abs(data['d']) * 100

# data를 넣어 줘야함, 안넣을 것이면 data['a'], (여러분과 데이터가 다를 것임)
plt.scatter('a','b', c='c', s='d', data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# plt.plt x, y 축에 대한 직접적 접근
plt.plot(data['a'], data['b'], 'o')
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# plt.plot x, y 축에 대해 parameter data 사용하여 접근
plt.plot('a', 'b', 'o', data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# plt.plot x, y, scale, color에 대한 setting
plt.scatter(data['a'], data['b'], s=data['d'], c=data['c'])
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# 추가적으로, x, y 축 라벨 설정
plt.scatter('a','b',c='c',s='d',data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # (Example) Mathplotlib을 이용한 시각화 (Bar Plot)

# %% [markdown]
# bar : 빈도수 표현식
# plt.bar(label, value)

# %%
# 변수 세팅
values = [50, 10, 100]
labels = ['A', 'B', 'C']
plt.bar(labels, values)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# # (Example) Mathplotlib을 이용한 시각화 (Figure 분할)

# %% [markdown]
# Figure 분할
# 1. figure(figure 개수, 분할 size)
#   subplot("행위치 열개수 열위치")

# %%
# 변수 세팅
x = np.arange(10)

plt.subplot(2,2,1)
plt.plot(x, x**2)

plt.subplot(2,2,2)
plt.plot(x, x*5)

# %%
# subplot 실습 1
names = ['A','B','C']
values = [50, 30, 100]

plt.figure(1, figsize=(9,3))

plt.subplot(1,3,1)
plt.bar(names, values)
plt.subplot(1,3,2)
plt.barh(names, values)
plt.subplot(1,3,3)
plt.scatter('a','b',c='c',s='d',data=data)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
# subplot 실습 2
x = np.arange(10)

plt.subplot(2,2,1)
plt.plot(x, x**2)

plt.subplot(2,2,2)
plt.plot(x, x*5)

plt.subplot(2,2,3)
plt.plot(x, np.sin(x))

plt.subplot(2,2,4)
plt.plot(x, np.cos(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # (Exercise) Mathplotlib을 이용한 시각화 (Figure 분할) - Question 2개

# %%
# subplot Question 1
# names : group_a, group_b, group_c
# values : 1, 10, 100
# To-do 1 (변수 설정)
names = ['group_a', 'group_b', 'group_c']
values = [1,10,100]
plt.figure(1, figsize=(9,3))

# To-do 2 (bar plot)
# position(1,3,1)
# x(names), y(values)
plt.subplot(1,3,1)
plt.bar(names, values)

# To-do 3 (Scatter plot)
# position(1,3,2)
# x(names), y(values)
plt.subplot(1,3,2)
plt.scatter(names, values)

# To-do 4 (plot)
# position(1,3,3)
# x(names), y(values)
plt.subplot(1,3,3)
plt.plot(names, values)

plt.suptitle('Categorical Plotting')
plt.show()

# %%
# subplot Question 2
# names : group_a, group_b, group_c, group_d
# values : 50, 100, 200, 350
# To-do 1 (변수 설정)
names = ['group_a', 'group_b', 'group_c', 'group_d']
values = [50, 100, 200, 350]
plt.figure(1, figsize=(15,10))

# To-do 2 (bar plot)
# position(2,2,1)
# x(names), y(values)
plt.subplot(2,2,1)
plt.bar(names, values)

# To-do 3 (Scatter plot)
# position(2,2,2)
# x(names), y(values)
plt.subplot(2,2,2)
plt.scatter(names, values)

# To-do 4 (plot)
# position(2,2,3)
# x(names), y(values)
plt.subplot(2,2,3)
plt.plot(names, values)

# To-do 5 (barh plot)
# position(2,2,4)
# x(names), y(values)
plt.subplot(2,2,4)
plt.barh(names, values)

plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# # (Example) Mathplotlib을 이용한 시각화 (Word Cloud)

# %% [markdown]
# Word Cloud : word가 발생한 빈도수를 기반으로 해주는 시각화

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
 
# 예시 text
text=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")
 
# word cloud 생성
plt.figure(1, figsize=(15,10))
wordcloud = WordCloud(width=1000, height=1000, margin=0).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# stopwords : 불용어에 대한 처리 기준 (Data Engineering 이 중요한 이유)

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
 
# 예시 text
text=("Python Python Python Matplotlib Matplotlib Seaborn Network Plot Violin Chart Pandas Datascience Wordcloud Spider Radar Parrallel Alpha Color Brewer Density Scatter Barplot Barplot Boxplot Violinplot Treemap Stacked Area Chart Chart Visualization Dataviz Donut Pie Time-Series Wordcloud Wordcloud Sankey Bubble")

# stopwords(불용어) 설정 
stopwords = set(STOPWORDS)
stopwords = ['Python', 'Seaborn','Chart']
stopwords.extend(stopwords)

# word cloud 생성
plt.figure(1, figsize=(15,10))
wordcloud = WordCloud(width=1000, height=1000, stopwords=stopwords, margin=0).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# # (Exercise) Mathplotlib을 이용한 시각화 (Word Cloud) - Question1

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# 구글 서치하셔서 영문 Text를 복사붙여넣기 해보세요 !!
# TO-DO1
text=("TO-DO1")
plt.figure(1, figsize=(15,10))

# stopwords(불용어) 설정
# TO-DO2
# stopwords(to, as, what, that, the)
stopwords = set(STOPWORDS)
stopwords = ['to', 'as','what','that','the']
stopwords.extend(stopwords)

# word cloud 생성
plt.figure(1, figsize=(15,10))
wordcloud = WordCloud(width=1000, height=1000, stopwords=stopwords, margin=0).generate(text)
 
# word cloud 시각화
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# # [Theme2] 이미지 시각화 imshow(ndarray)

# %%
# 이미지 다운로드
# !wget -O pic.jpg https://ojsfile.ohmynews.com/STD_IMG_FILE/2013/0712/IE001599011_STD.jpg
# !pip install pillow

# 이미지 업로드를 위한 Library Call
from PIL import Image

# 다운받은 이미지 로드
img = Image.open('pic.jpg')
# Out:
# --2020-09-15 23:01:29--  https://ojsfile.ohmynews.com/STD_IMG_FILE/2013/0712/IE001599011_STD.jpg
# Resolving ojsfile.ohmynews.com (ojsfile.ohmynews.com)... 211.237.6.217, 182.162.108.187, 182.162.108.188
# Connecting to ojsfile.ohmynews.com (ojsfile.ohmynews.com)|211.237.6.217|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42075 (41K) [image/jpeg]
# Saving to: ‘pic.jpg’
#
# pic.jpg             100%[===================>]  41.09K  43.4KB/s    in 0.9s
#
# 2020-09-15 23:01:32 (43.4 KB/s) - ‘pic.jpg’ saved [42075/42075]
#
# ...

# %%
#이미지를 numpy data로 변환
arr = np.array(img)

# shape 확인 (이미지 데이터는 3차원 데이터로 구성)
print(arr.shape)

# 컬러는 3차원, 흑백은 2차원 데이터
# matplotlib은 numpy ndarray를 imshow()로 ploting 할 수 있음
plt.imshow(arr)
# Out:
# (364, 482, 3)

# %% [markdown]
# ## *[Question] 그러면, Matplotlib 만 사용하면 될텐데 왜 Seaborn을 배우는 걸까?*

# %% [markdown]
# Mathplotlib vs. Seaborn 예시 비교

# %%
import seaborn as sns
df = sns.load_dataset("iris")
df.head(5)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Mathplotlib
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

df = sns.load_dataset("iris")
plt.bar(df["species"],df["petal_length"])
plt.xlabel("species")
plt.ylabel("petal_length")
plt.show()

# color / size 지정에는 더 많은 코드가 필요함

# %%
# Seaborn
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

df = sns.load_dataset("iris")
sns.barplot(x= "species",y= "sepal_length",data= df)
plt.show()

# %% [markdown]
# ## [Theme 3] Seaborn
#     - lineplot
#      * Exercise
#     - relplot
#      * Exercise
#     - boxplot
#      * Exercise
#     - swarmplot
#      * Exercise
#     - lmplot
#      * Exercise
#     - catplot(종합)
#      * Exercise
#     - heatmap
#      * Exercise
#     - pairplot
#      * Exercise
#     - barplot
#      * Exercise
#     - jointplot 외

# %% [markdown]
# Seaborn : 시각적으로 예쁘고, 간결한 구문을 제공 !!

# %%
# 시각화 작업을 위한 Library Call
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# notebook을 실행한 브라우저에서 그림을 바로 볼 수 있게 해줌 !
# %matplotlib inline

# 시각화 캔버스에 대한 grid 작업 (안넣어도 무방함)
sns.set_style("whitegrid")

# %% [markdown]
# # (Example) Seaborn을 이용한 시각화 (lineplot)

# %% [markdown]
# 시각화의 기본이라 할 수 있는, lineplot

# %%
# fmri dataset을 활용한 실습
fmri = sns.load_dataset("fmri")
fmri.head(5)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
# 기본적인 lineplot 시각화1
sns.lineplot(x="timepoint", y="signal", hue="region", data=fmri)

# %%
# 기본적인 lineplot 시각화2
sns.lineplot(x="timepoint", y="signal", hue="event",palette="Set3", data=fmri)

# %% [markdown]
# # (Exercise) Seaborn lineplot - Question 3개

# %%
# titanic dataset을 활용한 실습
titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
# lineplot - Question 1
# x(age), y(fare), hue(class)에 대한 lineplot 시각화 진행
# TO-DO
plt.figure(figsize=(8,6))
sns.lineplot(x="age", y="fare", hue = "class", data=titanic)
plt.show()

# %%
# tips dataset을 활용한 실습
tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# lineplot - Question 2
# x(size), y(total_bill), hue(smoker)에 대한 lineplot 시각화 진행
# TO-DO
plt.figure(figsize=(8,6))
sns.lineplot(x="size", y="total_bill", hue = "smoker", data=tips)
plt.show()

# %%
# tips dataset을 활용한 실습
penguins = sns.load_dataset("penguins")
penguins.head(5)
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    MALE
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  FEMALE
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  FEMALE
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  FEMALE
#
# [5 rows x 7 columns]

# %%
# lineplot - Question 3
# x(bill_length_mm), y(bill_depth_mm), hue(species)에 대한 lineplot 시각화 진행
# TO-DO
plt.figure(figsize=(8,6))
sns.lineplot(x="bill_length_mm", y="bill_depth_mm", hue = "species", data=penguins)
plt.show()

# %% [markdown]
# # (Example) Seaborn을 이용한 시각화 (relplot)

# %% [markdown]
# 관계열 시각화 Plotting 방법

# %%
# titanic dataset을 활용한 실습
titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
# x(age), y(fare), hue(class), col(who)에 대한 relplot 시각화 진행
# kind 파라미터 : Scatter 가 디폴트
sns.relplot(x="age", y="fare", hue = "class", col="who",data=titanic)
plt.show()

# %%
# x(age), y(fare), hue(class), col(who), row(survived)에 대한 relplot 시각화 진행
# kind = "line"
sns.relplot(x="age", y="fare", hue = "class", col="who", row="survived", kind='line',data=titanic)
plt.show()

# %%
# x(age), y(fare), hue(class), col(who)에 대한 relplot 시각화 진행
# kind 파라미터 : line
sns.relplot(x="age", y="fare", hue = "class", col="who", kind = "line", data=titanic)
plt.show()

# %%
# x(age), y(fare), hue(class), col(who)에 대한 relplot 시각화 진행
# data 내에서 sub query 를 통한, 필터링도 가능 (sex == 'male')
sns.relplot(x="age", y="fare", hue = "class", col="who", kind = "line", data = titanic.query("sex == 'male'"))
plt.show()

# %% [markdown]
# # (Exercise) Seaborn relplot - Question 3개

# %%
# penguins dataset을 활용한 Exercise
penguins = sns.load_dataset("penguins")
penguins.head(5)
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    MALE
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  FEMALE
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  FEMALE
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  FEMALE
#
# [5 rows x 7 columns]

# %%
# relplot - Question 1
# x(flipper_length_mm), y(body_mass_g), hue(sex), col(island)에 대한 relplot 시각화 진행
# TO-DO
plt.figure(figsize=(8,6))
sns.relplot(x="flipper_length_mm", y="body_mass_g", hue = "sex", col="island",data=penguins)
plt.show()

# %%
# relplot - Question 2
# x(bill_length_mm), y(bill_depth_mm), hue(species), col(island), row(sex)에 대한 relplot 시각화 진행
# Line 형태로 구성(Scatter Plot X)
# TO-DO
plt.figure(figsize=(8,6))
sns.relplot(x="bill_length_mm", y="bill_depth_mm", hue = "species", col="island", row="sex", kind="line",data=penguins)
plt.show()

# %%
# relplot - Question 3
# x(bill_length_mm), y(bill_depth_mm), hue(species), col(island), row(sex)에 대한 relplot 시각화 진행
# Line 형태로 구성(Scatter Plot X)
# 필터 : bill_depth_mm < 20
# TO-DO
plt.figure(figsize=(8,6))
sns.relplot(x="bill_length_mm", y="bill_depth_mm", hue = "species", col="island", row="sex", kind="line",data=penguins.query("bill_depth_mm < 20"))
plt.show()

# %% [markdown]
# # (Example) Seaborn을 이용한 시각화 (boxplot)

# %% [markdown]
# **[중요]** Boxplot은 EDA / 머신러닝 작업에서 2~3개 그룹간의 비교, 2개 클래스를 잘 분류할 수 있는 변수를 찾는데 가장 많이 사용됨

# %%
# tips dataset을 활용한 실습
tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 기본적인 boxplot 시각화 (y축 기준)
sns.boxplot(y='tip', data=tips)

# %%
# 기본적인 boxplot 시각화 (x축 기준)
sns.set_style("whitegrid")
plt.figure(figsize=(8,6))

# 뒤에 'data = tips'을 쓰지 않으면, df 형태에서 접근하는 방법도 가능 df['컬럼명'] 
sns.boxplot(x=tips["total_bill"])
plt.show()

# %%
# 기본적인 boxplot 시각화 (x, y 2개 축 기준)
plt.figure(figsize=(8,6))
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
# x(sex), y(total_bill), hue(smoker) 별로 boxplot 그리기
# hue(smoker) 세팅 시, 범례 자동으로 표시 됨
sns.boxplot(x='sex', y='total_bill', hue='smoker', data=tips, palette="Set3")
plt.show()

# %%
# x(day), y(tip), hue(smoker) 별로 boxplot 그리기
plt.figure(figsize=(8,6))
sns.boxplot(x="day", y="tip", hue="smoker", data=tips, palette="Set3")
plt.show()

# %% [markdown]
# # (Example) Seaborn을 이용한 시각화 (swarmplot)

# %% [markdown]
# **[중요]** boxplot보다 원본 데이터의 분포를 더 자세하게 확인할 때 사용

# %%
# tips dataset을 활용한 실습
tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# swarmplot 함수를 통한, 시각화 진행
plt.figure(figsize=(8,6))
sns.swarmplot(x="day", y="total_bill", data=tips, color=".5", size=6)
plt.show()

# %%
# swarmplot 함수를 통한, 시각화 진행
plt.figure(figsize=(8,6))
sns.swarmplot(x="day", y="total_bill", hue = "time", data=tips, size=6)
plt.show()

# %%
# swarmplot + boxplot 함수를 통한, 시각화 진행
plt.figure(figsize=(8,6))
sns.boxplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x="day", y="total_bill", data=tips, color=".25")
plt.show()

# %% [markdown]
# # (Exercise) Seaborn boxplot, swamplot - Question 3개

# %%
# titanic dataset을 활용한 실습
titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
# swarmplot - Question 1
# x(class), y(age), hue(sex)에 대한 swarmplot 시각화 진행
# TO-DO
plt.figure(figsize=(8,6))
sns.swarmplot(x="class", y="age", hue = "sex", data=titanic, size=6)
plt.show()

# %%
# swarmplot + boxplot - Question 2
# x(class), y(age), hue(sex)에 대한 swarmplot 시각화 진행
# TO-DO
plt.figure(figsize=(8,6))
sns.boxplot(x="class", y="fare", data=titanic)
sns.swarmplot(x="class", y="fare", data=titanic, color=".25", size = 3)
plt.show()

# %%
# penguins dataset을 활용한 Exercise
penguins = sns.load_dataset("penguins")
penguins.head(5)
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    MALE
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  FEMALE
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  FEMALE
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  FEMALE
#
# [5 rows x 7 columns]

# %%
# swarmplot + boxplot - Question 3
# x(species), y(bill_length_mm), hue(sex)에 대한 boxplot 시각화 진행
# x(species), y(bill_length_mm)에 대한 swarmplot 시각화 진행
# TO-DO
plt.figure(figsize=(8,6))
sns.boxplot(x="species", y="bill_length_mm", hue="sex",data=penguins)
sns.swarmplot(x="species", y="bill_length_mm", data=penguins, color=".25", size = 3)
plt.show()

# %% [markdown]
# ## (Training) boxplot 활용, MPG Dataset에 대한 자유 시각화 (시간 : 10 min.)
#
# ---

# %%
# mpg dataset을 활용한 실습
mpg = sns.load_dataset("mpg")
mpg.head(5)
# Out:
#     mpg  cylinders  displacement  ...  model_year  origin                       name
# 0  18.0          8         307.0  ...          70     usa  chevrolet chevelle malibu
# 1  15.0          8         350.0  ...          70     usa          buick skylark 320
# 2  18.0          8         318.0  ...          70     usa         plymouth satellite
# 3  16.0          8         304.0  ...          70     usa              amc rebel sst
# 4  17.0          8         302.0  ...          70     usa                ford torino
#
# [5 rows x 9 columns]

# %%
# TO-DO 1
# 자유 시각화 1
plt.figure(figsize=(8,6))
sns.boxplot(x="model_year", y="mpg", hue="origin", data=mpg, palette="Set3")
sns.swarmplot(x="model_year", y="mpg", hue="origin", data=mpg, palette="Set3")

plt.show()

# %%
# TO-DO 2
# 자유 시각화 2
plt.figure(figsize=(8,6))
sns.boxplot(x="origin", y="mpg", hue="model_year", data=mpg, palette="Set1")
plt.show()

# %% [markdown]
# # (Example) Seaborn을 이용한 시각화 (lmplot)

# %% [markdown]
# lmplot을 통해 회귀(Regression) 그래프에 대한 생성이 가능함

# %%
# tips dataset을 활용한 실습
tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# lmplot 함수를 통한, 시각화 진행
sns.set_style("darkgrid")
sns.lmplot(x="total_bill", y="tip", data=tips, size=7)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# lmplot 함수에, hue 값을 이용한 카테고리 구분
# marker(표시 형식) 에 대한 세팅도 가능
sns.lmplot(x="total_bill", y="tip", hue="smoker", markers=["o","x"], data=tips, size=7)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# lmplot 함수에서, color palette 설정
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips, palette="Set1", size=7)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # (Exercise) Seaborn lmplot - Question 2개

# %%
# titanic dataset을 활용한 Exercise
titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
# lmplot - Question 1
# x(class), y(age), hue(sex)에 대한 lmplot 시각화 진행
# TO-DO
sns.lmplot(x="age", y="fare", hue="class", data=titanic, palette="Set1", size=7)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
# lmplot - Question 2
# x(fare), y(age), hue(survived)에 대한 lmplot 시각화 진행
# markers 설정(2개 : o, x)
# TO-DO
sns.lmplot(x="fare", y="age", hue="survived", data=titanic, markers=["o","x"], size=10)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/regression.py:573: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # (Example) Seaborn을 이용한 시각화 (catplot(종합))

# %% [markdown]
# 숫자형 변수와 하나 이상의 범주형 변수의 관계를 보여주는 시각화
# - kind = point, bar, count, box, violin, boxen, ...

# %%
# exercise dataset을 활용한 실습
exercise = sns.load_dataset("exercise")
exercise.head(5)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
# catplot 함수를 통한, 시각화 진행 (kind="point")
sns.catplot(x="time", y="pulse", hue="kind", col="diet", kind="point", data=exercise)
#sns.catplot(x="time", y="pulse", hue="kind", col="diet", capsize=.2, height=6, aspect=.75, kind="point", data=exercise)
plt.plot()
# Out:
# []

# %%
# catplot 함수를 통한, 시각화 진행 (kind="bar")
sns.catplot(x="time", y="pulse", hue="kind", col="diet",row='kind', kind="bar", data=exercise)
plt.plot()
# Out:
# []

# %%
# catplot 함수를 통한, 시각화 진행 (kind="box")
sns.catplot(x="time", y="pulse", hue="kind", col="diet", kind="box", data=exercise)
plt.plot()
# Out:
# []

# %%
# catplot 함수를 통한, 시각화 진행 (kind="violin")
sns.catplot(x="time", y="pulse", hue="kind", col="diet", kind="violin", data=exercise)
plt.plot()
# Out:
# []

# %%
# catplot 함수를 통한, 시각화 진행 (kind="boxen")
sns.catplot(x="time", y="pulse", hue="kind", col="diet", kind="boxen", data=exercise)
plt.plot()
# Out:
# []

# %% [markdown]
# # (Exercise) Seaborn catplot(종합) - Question 3개

# %%
# penguins dataset을 활용한 실습
penguins = sns.load_dataset("penguins")
penguins.head(5)
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    MALE
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  FEMALE
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  FEMALE
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  FEMALE
#
# [5 rows x 7 columns]

# %%
# Question 1
# catplot 함수를 통한, 시각화 진행 (kind="box")
# x(sex), y(flipper_length_mm), hue(species), col(island), row(sex)에 대한 catplot 시각화 진행
# boxplot 형태로 구성
# 필터 : body_mass_g > 3000, bill_length_mm > 30
# TO-DO
sns.catplot(x="sex", y="flipper_length_mm", hue = "species", col="island", row="sex", kind="box",data=penguins.query("body_mass_g > 3000 & bill_length_mm > 30"))
plt.plot()
# Out:
# []

# %%
# Question 2
# catplot 함수를 통한, 시각화 진행 (kind="point")
# x(sex), y(bill_length_mm), hue(species), col(island)에 대한 catplot 시각화 진행
# pointplot 형태로 구성
# 필터 : bill_length_mm > 30
# TO-DO
sns.catplot(x="sex", y="bill_length_mm", hue = "species", col="island", kind="point",data=penguins.query("bill_length_mm > 30"))
plt.plot()
# Out:
# []

# %%
# titanic dataset을 활용한 실습
titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
# Question 3
# catplot 함수를 통한, 시각화 진행 (kind="violin")
# x(survived), y(age), hue(class), col(alive)에 대한 catplot 시각화 진행
# pointplot 형태로 구성
# 필터 : fare > 10, age < 50
# TO-DO
sns.catplot(x="survived", y="age", hue = "class", col="sex", kind="violin", data=titanic.query("fare > 10 & age < 50"))
plt.plot()
# Out:
# []

# %% [markdown]
# # (Example) Seaborn을 이용한 시각화 (heatmap)

# %% [markdown]
# heatmap을 통해, 두 개의 카테고리 값에 의한 실수의 변화를 보고자 할 경우에 사용

# %%
# 시각화를 위한, flights Data Loading
flights = sns.load_dataset("flights")
flights.head(5)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
# heatmap으로 만들기 위한, pivot_table 함수를 사용
flights = flights.pivot("month", "year", "passengers")
flights.head(5)
# Out:
# year      1949  1950  1951  1952  1953  ...  1956  1957  1958  1959  1960
# month                                   ...
# January    112   115   145   171   196  ...   284   315   340   360   417
# February   118   126   150   180   196  ...   277   301   318   342   391
# March      132   141   178   193   236  ...   317   356   362   406   419
# April      129   135   163   181   235  ...   313   348   348   396   461
# May        121   125   172   183   229  ...   318   355   363   420   472
#
# [5 rows x 12 columns]

# %%
# heatmap 함수를 통한, 시각화 진행
plt.figure(figsize=(10,8))
sns.heatmap(flights)
plt.show()

# %%
# annot 옵션을 통한, value 값 출력 가능
# fmt(포맷팅) 옵션을 통한, 데이터 형식 지정 가능(d: 정수, f:실수)
plt.figure(figsize=(10,8))
sns.heatmap(flights, annot=True, fmt="d")
plt.show()

# %% [markdown]
# # (Exercise) Seaborn heatmap - Question 2개

# %%
# tips dataset을 활용한 실습
flights = sns.load_dataset("flights")
flights.head(5)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
# heatmap - Question 1
# 행(year), 열(month), 값(passengers) pivot table 화하여 flights_ex 변수에 저장
# TO-DO
flights_ex = flights.pivot("year", "month", "passengers")
flights_ex.head(5)
# Out:
# month  January  February  March  April  ...  September  October  November  December
# year                                    ...
# 1949       112       118    132    129  ...        136      119       104       118
# 1950       115       126    141    135  ...        158      133       114       140
# 1951       145       150    178    163  ...        184      162       146       166
# 1952       171       180    193    181  ...        209      191       172       194
# 1953       196       196    236    235  ...        237      211       180       201
#
# [5 rows x 12 columns]

# %%
# heatmap - Question 2
# flights_ex pivot table에 대한 heatmap 시각화 진행
# TO-DO
plt.figure(figsize=(10,8))
sns.heatmap(flights_ex, annot=True, fmt="d")

# %% [markdown]
# # (Example) Seaborn을 이용한 시각화 (pairplot)
# pairplot 함수를 이용하여, 데이터의 분포 및 변수간 관계 분석이 가능

# %%
# 시각화를 위한, iris Data Loading
sns.set(style="ticks")
iris = sns.load_dataset("iris")
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
# pairplot을 통하느 변수(컬럼)간 관계와 분포 확인 가능
sns.pairplot(iris)
plt.show()

# %%
# hue 옵션을 이용하여, 카테고리 별 변수의 관계와 분포 확인 가능
sns.pairplot(iris, hue='species')

# %%
# vars 옵션을 사용하여, 특정 변수만 지정해서 볼 수 있음
sns.pairplot(iris, vars=['sepal_width', 'sepal_length'])

# %%
# seaborn pairplot (x_vars, y_vars 사용)
sns.pairplot(iris, x_vars=['sepal_width','sepal_length'], y_vars=['petal_width','petal_length'])

# %% [markdown]
# # (Exercise) Seaborn pairplot - Question 2개

# %%
# tips dataset을 활용한 실습
tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# pairplot - Question 1
# tips dataframe에 대해, 변수에 대한 관계와 분포를 그려보시오 ! (카테고리 : sex)
# TO-DO
sns.pairplot(tips, hue='sex')

# %%
# pairplot - Question 2
# tips dataframe에 대해, x축(total_bill, tip), y축(day, size)에 대한 pairplot을 그려보시오 !
# TO-DO
sns.pairplot(tips, x_vars=['total_bill','tip'], y_vars=['day','size'])

# %% [markdown]
# # (Example) Seaborn을 이용한 시각화 (barplot)
# barplot 함수를 이용하여, 다양한 집계 값에 대한 표현이 가능함

# %%
# titanic dataset을 활용한 실습
titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
# barplot draw (default : 평균값을 의미)
sns.barplot(data=titanic, x="class", y="survived")

# 갑자기 나타난, 세로 선은 무엇일까? '오차 막대'
# 오차막대(Error Bar) : 이 데이터를 기반으로 유사한 상황의 95%가 이 범위 내의 결과를 얻을 것을 의미함

# %%
# barplot draw (default : 평균값을 의미)
sns.barplot(data=titanic, x="class", y="survived", estimator=len)

# %% [markdown]
# ## (Exercise) Seaborn barplot - Question 3개

# %%
import numpy as np

# titanic dataset을 활용한 실습
titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
# question 1
# x(class), y(age), hue(survived) 에 대한 borplot을 그려보시오. (mean 값 활용)
# TO-DO
sns.barplot(data=titanic, x="class", y="age", hue="survived")
plt.show()

# %%
# question 2
# x(who), y(age), hue(survived) 에 대한 borplot을 그려보시오. (median 값 활용)
# TO-DO
sns.barplot(data=titanic, x="who", y="age", hue="survived", estimator=np.median)
plt.show()

# %%
# titanic dataset을 활용한 실습
penguins = sns.load_dataset("penguins")
penguins.head(5)
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    MALE
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  FEMALE
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  FEMALE
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  FEMALE
#
# [5 rows x 7 columns]

# %%
# question 3
# x(species), y(flipper_length_mm), hue(sex) 에 대한 borplot을 그려보시오. (mean 값 활용)
# TO-DO
sns.barplot(data=penguins, x="species", y="flipper_length_mm", hue="sex", estimator=np.mean)
plt.show()

# %% [markdown]
# # (Exampe) 다양한 시각화 제공 (Jointplot, countplot 등)

# %% [markdown]
# Jointplot : 안쪽은 점 데이터로 분포를 확인하고, 바깓쪽은 막대 그래프로 밀집도를 확인하는 시각화

# %%
# tips dataset을 활용한 실습
tips = sns.load_dataset("tips")
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Parameter kind에 아무것도 넣지 않으면, Default : scatter plot
joint = sns.jointplot(x='total_bill', y='tip', data=tips)
plt.show()

# x, y label setting
joint.set_axis_labels(xlabel='TB', ylabel='Tip')

# %%
# Parameter kind : reg(회귀선)
joint = sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')
plt.show()

# %%
# Parameter kind : hex(hexbin)
joint = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex')
plt.show()

# %%
# Parameter kind : kde (kernel density estimation)
joint = sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')
plt.show()

# %%
# Parameter kind : hex
# joint = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex', color="grey")
joint = sns.jointplot(x='total_bill', y='tip', data=tips, kind='hex', color="grey", space=0)
plt.show()

# %% [markdown]
# countplot : 지정한 컬럼 별 모수를 보여주는 barchart

# %%
# titanic dataset을 활용한 실습
titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
# 카테고리별 카운트 가능
sns.countplot(x="sex", data=titanic)
plt.title("title name")
# Out:
# Text(0.5, 1.0, 'title name')

# %% [markdown]
# ## [Theme 4] Seaborn 활용하여, Dataset 3종에 대한 자유 시각화 (시간 : 20 min.)
#     - titanic, penguins Dataset 활용하여 Seaborn 시각화 자유롭게 진행해보기 !!
#     - 시각화 진행과 더불어, 도출할 수 있는 인사이트를 알아보기 !!
#     - 수강생 中 세 분 발표 진행 예정 (인당, 5 min. 발표 진행) !!

# %%
# 시각화 작업을 위한 Library Call
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# notebook을 실행한 브라우저에서 그림을 바로 볼 수 있게 해줌 !
# %matplotlib inline

# %%
# titanic dataset을 활용한 실습
titanic = sns.load_dataset("titanic")
titanic.head(5)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
# 3         1       1  female  35.0  ...     C  Southampton    yes  False
# 4         0       3    male  35.0  ...   NaN  Southampton     no   True
#
# [5 rows x 15 columns]

# %%
# TO-DO 1
# 자유 시각화 1
plt.figure(figsize=(8,6))
sns.catplot(x="alive", y="age", hue="class", col="sex", kind="box", data=titanic, palette="Set3")
plt.show()

# %%
# penguins dataset을 활용한 실습
penguins = sns.load_dataset("penguins")
penguins.head(5)
# Out:
#   species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0  Adelie  Torgersen            39.1  ...              181.0       3750.0    MALE
# 1  Adelie  Torgersen            39.5  ...              186.0       3800.0  FEMALE
# 2  Adelie  Torgersen            40.3  ...              195.0       3250.0  FEMALE
# 3  Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4  Adelie  Torgersen            36.7  ...              193.0       3450.0  FEMALE
#
# [5 rows x 7 columns]

# %%
# TO-DO 2
# 자유 시각화 2
plt.figure(figsize=(8,6))
sns.catplot(x="island", y="bill_length_mm", hue="species", col="sex", kind="box", data=penguins, palette="Set3")
plt.show()

# %%
# exercise dataset을 활용한 실습
exercise = sns.load_dataset("exercise")
exercise.head(5)
# Out:
#    Unnamed: 0  id     diet  pulse    time  kind
# 0           0   1  low fat     85   1 min  rest
# 1           1   1  low fat     85  15 min  rest
# 2           2   1  low fat     88  30 min  rest
# 3           3   2  low fat     90   1 min  rest
# 4           4   2  low fat     92  15 min  rest

# %%
# 자유 시각화 3
plt.figure(figsize=(8,6))
sns.catplot(x="diet", y="pulse", kind="box",  col="kind", data=exercise.query("pulse < 100"), palette="Set3")
plt.show()

# %% [markdown]
# # d3.js : 국/내외 시각화 업계 대세인, 자바스크립트 기반 데이터 시각화 Library

# %% [markdown]
# - Standford University에서 배포했으며, 가장 강력한 시각화 패키지 보유
#   * '딥러닝' -> 'Tensor Flow' 가 떠오르는 것 처럼, '시각화' -> 'd3.js'

# %% [markdown]
# https://observablehq.com/@d3/gallery

# %% [markdown]
# https://www.gapminder.org/
